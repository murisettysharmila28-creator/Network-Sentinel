# %%
import os
import pandas as pd

# Absolute path to your dataset (this is the key fix)
file_path = r"C:\Sharmila\Machine Learning\Projects\Network-Sentinel\data\raw\Wednesday-workingHours.pcap_ISCX.csv"

# Load dataset
df = pd.read_csv(file_path, low_memory=False)

# Create processed folder in PROJECT (not env)
output_dir = r"C:\Sharmila\Machine Learning\Projects\Network-Sentinel\data\processed"
os.makedirs(output_dir, exist_ok=True)

# Sample
sample_df = df.sample(n=1000, random_state=42)

# Save
output_path = os.path.join(output_dir, "test_sample.csv")
sample_df.to_csv(output_path, index=False)

print(f"Saved at: {output_path}")
# Out:
# Saved at: C:\Sharmila\Machine Learning\Projects\Network-Sentinel\data\processed\test_sample.csv
